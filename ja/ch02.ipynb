# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 第2章: UNIXコマンド
#
# [popular-names.txt](/data/popular-names.txt)は、アメリカで生まれた赤ちゃんの「名前」「性別」「人数」「年」をタブ区切り形式で格納したファイルである。以下の処理を行うプログラムを作成し、[popular-names.txt](/data/popular-names.txt)を入力ファイルとして実行せよ。さらに、同様の処理をUNIXコマンドでも実行し、プログラムの実行結果を確認せよ。

# %% [markdown]
# ## 10. 行数のカウント
# ファイルの行数をカウントせよ。確認にはwcコマンドを用いよ。

# %%
def count(file):
   with open(file, 'r') as f:
      lines = f.readlines()
      return len(lines)

# %%
print(count('/content/drive/MyDrive/popular-names.txt'))
# Out:
# 2780

# %%
# !wc /content/drive/MyDrive/popular-names.txt
# Out:
#  2780 11120 55026 /content/drive/MyDrive/popular-names.txt

# %% [markdown]
# ## 11. 先頭からN行を出力
# ファイルの先頭N行だけを表示せよ。例えば、N=10として先頭10行を表示せよ。確認にはheadコマンドを用いよ。

# %%
def head(file, n):
  output = []
  with open(file, 'r') as f:
    for i, line in enumerate(f):
      if i < n:
        output.append(line)
  return ''.join(output)

# %%
print(head('/content/drive/MyDrive/popular-names.txt', 10))
# Out:
# Mary	F	7065	1880
# Anna	F	2604	1880
# Emma	F	2003	1880
# Elizabeth	F	1939	1880
# Minnie	F	1746	1880
# Margaret	F	1578	1880
# Ida	F	1472	1880
# Alice	F	1414	1880
# Bertha	F	1320	1880
# Sarah	F	1288	1880

# %%
# !head -n 10 /content/drive/MyDrive/popular-names.txt
# Out:
# Mary	F	7065	1880
# Anna	F	2604	1880
# Emma	F	2003	1880
# Elizabeth	F	1939	1880
# Minnie	F	1746	1880
# Margaret	F	1578	1880
# Ida	F	1472	1880
# Alice	F	1414	1880
# Bertha	F	1320	1880
# Sarah	F	1288	1880

# %% [markdown]
# ## 12. 末尾のN行を出力
# ファイルの末尾N行だけを表示せよ。例えば、N=10として末尾10行を表示せよ。確認にはtailコマンドを用いよ。

# %%
def tail(file, n):
  output = []
  with open(file, 'r') as f:
    start = count(file) - n
    lines = f.readlines()
    for i, line in enumerate(lines):
      if start-1 < i < count(file):
        output.append(line)
  return ''.join(output)

# %%
print(tail('/content/drive/MyDrive/popular-names.txt', 10))
# Out:
# Liam	M	19837	2018
# Noah	M	18267	2018
# William	M	14516	2018
# James	M	13525	2018
# Oliver	M	13389	2018
# Benjamin	M	13381	2018
# Elijah	M	12886	2018
# Lucas	M	12585	2018
# Mason	M	12435	2018
# Logan	M	12352	2018

# %%
# !tail -n 10 /content/drive/MyDrive/popular-names.txt
# Out:
# Liam	M	19837	2018
# Noah	M	18267	2018
# William	M	14516	2018
# James	M	13525	2018
# Oliver	M	13389	2018
# Benjamin	M	13381	2018
# Elijah	M	12886	2018
# Lucas	M	12585	2018
# Mason	M	12435	2018
# Logan	M	12352	2018

# %% [markdown]
# ## 13. タブをスペースに置換
# ファイルの先頭10行に対して、タブ1文字につきスペース1文字に置換して出力せよ。確認にはsedコマンド、trコマンド、もしくはexpandコマンドなどを用いよ。

# %%
lines = head('/content/drive/MyDrive/popular-names.txt', 10)

for s in lines.replace('\t', ' '):
  print(s, end='')
# Out:
# Mary F 7065 1880
# Anna F 2604 1880
# Emma F 2003 1880
# Elizabeth F 1939 1880
# Minnie F 1746 1880
# Margaret F 1578 1880
# Ida F 1472 1880
# Alice F 1414 1880
# Bertha F 1320 1880
# Sarah F 1288 1880

# %%
# !head -n 10 /content/drive/MyDrive/popular-names.txt | sed 's/\t/ /g'
# Out:
# Mary F 7065 1880
# Anna F 2604 1880
# Emma F 2003 1880
# Elizabeth F 1939 1880
# Minnie F 1746 1880
# Margaret F 1578 1880
# Ida F 1472 1880
# Alice F 1414 1880
# Bertha F 1320 1880
# Sarah F 1288 1880

# %% [markdown]
# ## 14. 1列目を出力
# ファイルの先頭10行に対して、各行の1列目だけを抜き出して表示せよ。確認にはcutコマンドなどを用いよ。

# %%
lines = head('/content/drive/MyDrive/popular-names.txt', 10)

for s in lines.split('\n'):
    print(s.split('\t')[0])
# Out:
# Mary
# Anna
# Emma
# Elizabeth
# Minnie
# Margaret
# Ida
# Alice
# Bertha
# Sarah

# %%
# !head -n 10 /content/drive/MyDrive/popular-names.txt |cut -f 1
# Out:
# Mary
# Anna
# Emma
# Elizabeth
# Minnie
# Margaret
# Ida
# Alice
# Bertha
# Sarah

# %% [markdown]
# ## 15. ファイルをN分割する
# ファイルを行単位でN分割し、別のファイルに格納せよ。例えば、N=10としてファイルを10分割せよ。同様の処理をsplitコマンドで実現せよ。

# %%
def split(file, n, output_prefix="x"):
  with open(file, 'r') as f:
    lines = f.readlines()
  total = len(lines)
  sp = total // n
  remainder = total % n

  start_index = 0
  for i in range(n):
    end_index = start_index + sp
    if i < remainder: # Distribute remainder lines among the first 'remainder' files
      end_index += 1

    # Generate output filename (e.g., xa, xb, xc, ...) compatible with 'split' command naming
    output_filename = f"{output_prefix}{chr(ord('a') + i)}"
    with open(output_filename, 'w') as out_f:
      out_f.writelines(lines[start_index:end_index])
    start_index = end_index

# %%
split('/content/drive/MyDrive/popular-names.txt', 10)
# !ls xa*
# Out:
# xa  xaa  xab  xac  xad	xae  xaf  xag  xah  xai  xaj

# %%
file = "/content/drive/MyDrive/popular-names.txt"
num = count(file)/10
print(num)
# Out:
# 278.0

# %%
# !split -l 278 /content/drive/MyDrive/popular-names.txt

# %% [markdown]
# ## 16. ランダムに各行を並び替える
# ファイルを行単位でランダムに並び替えよ（注意: 各行の内容は変更せずに並び替えよ）。同様の処理をshufコマンドで実現せよ。

# %% [markdown]
# ## 17. １列目の文字列の異なり
# 1列目の文字列の異なり（文字列の種類）を求めよ。確認にはcut, sort, uniqコマンドを用いよ。

# %% [markdown]
# ## 18. 各行の1列目の文字列の出現頻度を求め、出現頻度の高い順に並べる
# 1列目の文字列の出現頻度を求め、出現頻度と名前を出現頻度の多い順に並べて表示せよ。確認にはcut, uniq, sortコマンドを用いよ。

# %% [markdown]
# ## 19. 3列目の数値の降順に各行を並び替える
# 3列目の数値の逆順でファイルの各行を整列せよ（注意: 各行の内容は変更せずに並び替えよ）。同様の処理をsortコマンドで実現せよ。
